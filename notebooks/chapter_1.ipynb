# %% [markdown]
# Test of a first line of explantion

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# You can define a list as:

# %%
L = [1, 2, 3]

# %% [markdown]
# You can pass a shell command in python by adding `!` before the code line

# %%
# !ls
# Out:
# chapter_1.ipynb

# %% [markdown]
# This can be useful, for example, to work with the different directories inside a folder:

# %%
contents = !ls
print(contents)

directory = !pwd
print(directory)
# Out:
# ['chapter_1.ipynb']
# ['/home/drodgu/python_data_analyst_tutorial/notebooks']
